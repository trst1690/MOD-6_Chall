# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
import os


#file_path = os.path.join(os.getcwd(), "output_data", "cities.csv")
#city_data_df = pd.read_csv(file_path)

city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
#%%capture --no-display

# Configure the map plot
# YOUR CODE HERE
#min_size = 5  # Minimum marker size
#max_size = 20  # Maximum marker size
#humidity_min = city_data_df['Humidity'].min()
#humidity_max = city_data_df['Humidity'].max()
#city_data_df['size'] = ((city_data_df['Humidity'] - humidity_min) / (humidity_max - humidity_min)) \
    #* (max_size - min_size) + min_size

map_plot = city_data_df.hvplot.points(
    x='Lng',  # Replace 'longitude' with the actual column name containing longitude values
    y='Lat',  # Replace 'latitude' with the actual column name containing latitude values
    c='Humidity',  # Replace 'humidity' with the actual column name containing humidity values
    geo=True,  # Enable geographic projection
    size='Humidity',  # Set the size of the points to represent humidity
    color='blue',  # Set the color of the points
    alpha=0.7,  # Set the transparency of the points
    tiles = "EsriNatGeo",
    hover_cols=['City', 'Humidity'],  # Show city and humidity in the hover tooltip
    width=800,  # Set the width of the plot
    height=500  # Set the height of the plot
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
IWC_df = city_data_df.loc[(city_data_df["Max Temp"] >20) & (city_data_df.loc["Max Temp"] =< 30) & (city_data_df.loc["Cloudiness"] == 0)]

# Drop any rows with null values
# YOUR CODE HERE
IWC_df = IWC_df.dropna(how="any")

# Display sample data
# YOUR CODE HERE
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 45        45           kapaa  22.0752 -159.3190     22.99        84
# 51        51            hilo  19.7297 -155.0900     26.27        83
# 63        63           banda  25.4833   80.3333     24.62        52
# 81        81   makakilo city  21.3469 -158.0858     21.66        81
# 152      152         kahului  20.8947 -156.4700     23.80        60
# 197      197             gat  31.6100   34.7642     24.38       100
# 211      211          laguna  38.4210 -121.4238     21.67        79
# 240      240     tikaitnagar  26.9500   81.5833     23.56        59
# 265      265     san quintin  30.4833 -115.9500     21.20        74
# 340      340   santa rosalia  27.3167 -112.2833     24.62        56
# 363      363          narwar  25.6500   77.9000     22.35        55
# 375      375    port hedland -20.3167  118.5667     21.03        73
# 381      381       roebourne -20.7833  117.1333     23.48        65
# ...

# %%
IWC_df = city_data_df.loc[(city_data_df["Max Temp"] >20) & (city_data_df["Max Temp"] <= 30) & (city_data_df["Cloudiness"] == 0)]

IWC_df = IWC_df.dropna(how="any")

IWC_df.head()
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 7         7     carnarvon -24.8667  113.6333     20.02        76           0
# 9         9  saint-pierre -21.3393   55.4781     22.82        68           0
# 32       32     cape town -33.9258   18.4232     20.61        71           0
# 45       45         kapaa  22.0752 -159.3190     22.99        84           0
# 51       51          hilo  19.7297 -155.0900     26.27        83           0
#
#     Wind Speed Country        Date
# 7         7.46      AU  1666108232
# 9         5.14      RE  1666108236
# 32        9.26      ZA  1666108250
# 45        3.60      US  1666108257
# 51        2.57      US  1666108260

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 45            kapaa      US  22.0752 -159.3190        84
# 51             hilo      US  19.7297 -155.0900        83
# 63            banda      IN  25.4833   80.3333        52
# 81    makakilo city      US  21.3469 -158.0858        81
# 152         kahului      US  20.8947 -156.4700        60
# 197             gat      IL  31.6100   34.7642       100
# 211          laguna      US  38.4210 -121.4238        79
# 240     tikaitnagar      IN  26.9500   81.5833        59
# 265     san quintin      MX  30.4833 -115.9500        74
# 340   santa rosalia      MX  27.3167 -112.2833        56
# 363          narwar      IN  25.6500   77.9000        55
# 375    port hedland      AU -20.3167  118.5667        73
# 381       roebourne      AU -20.7833  117.1333        65
# 391  saint-francois      FR  46.4154    3.9054        57
# 409       capoterra      IT  39.1763    8.9718        71
# ...

# %%
hotel_df = IWC_df[["City","Country","Lat", "Lng","Humidity"]]
hotel_df['Hotel Name'] = ''
hotel_df.head(20)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2628\1653170379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ''
#                    City Country      Lat       Lng  Humidity Hotel Name
# 7             carnarvon      AU -24.8667  113.6333        76
# 9          saint-pierre      RE -21.3393   55.4781        68
# 32            cape town      ZA -33.9258   18.4232        71
# 45                kapaa      US  22.0752 -159.3190        84
# 51                 hilo      US  19.7297 -155.0900        83
# 63                banda      IN  25.4833   80.3333        52
# 73                nalut      LY  30.3333   10.8500        27
# 81        makakilo city      US  21.3469 -158.0858        81
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000# YOUR CODE HERE
params = {
    "categories":"accommodation.hotel",
    "limit":16,
    "apiKey":geoapify_key,
    # YOUR CODE HERE
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    lat = hotel_df.loc["Lat"]
    lng = hotel_df.loc["Lng"]
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"ciricle:{lat},{lng},{radius}"# YOUR CODE HERE
    params["bias"] = f"Proximity:{lng},{lat}"# YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)# YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address =  name_address.json()# YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# kapaa - nearest hotel: Pono Kai Resort
# hilo - nearest hotel: Dolphin Bay Hotel
# banda - nearest hotel: #acnindiafy21
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# kahului - nearest hotel: Maui Seaside Hotel
# gat - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# tikaitnagar - nearest hotel: No hotel found
# san quintin - nearest hotel: Jardines Hotel
# santa rosalia - nearest hotel: Hotel del Real
# narwar - nearest hotel: No hotel found
# port hedland - nearest hotel: The Esplanade Hotel
# roebourne - nearest hotel: No hotel found
# saint-francois - nearest hotel: Chez Lily
# capoterra - nearest hotel: Rosa Hotel
# stolac - nearest hotel: Bregava
# guerrero negro - nearest hotel: Plaza sal paraiso
#                City Country      Lat       Lng  Humidity  \
# 45            kapaa      US  22.0752 -159.3190        84
# 51             hilo      US  19.7297 -155.0900        83
# ...

# %%
radius = 100000
params = {
    "categories":"accommodation.hotel",
    "limit":16,
    "apiKey":geoapify_key,
   
}
print("Starting hotel search")

for index, row in hotel_df.iterrows():
    lat = hotel_df.loc[index,"Lat"]
    lng = hotel_df.loc[index,"Lng"]
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    base_url = "https://api.geoapify.com/v2/places"
    name_address = requests.get(base_url, params=params)
    #print(f"Response status code: {name_address.status_code}")
    name_address =  name_address.json()
    #print(f"Response JSON: {name_address}")
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

hotel_df
# Out:
# Starting hotel search
# carnarvon - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# cape town - nearest hotel: Townhouse Hotel
# kapaa - nearest hotel: Pono Kai Resort
# hilo - nearest hotel: Dolphin Bay Hotel
# banda - nearest hotel: #acnindiafy21
# nalut - nearest hotel: فندق القصر
# makakilo city - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# puerto del rosario - nearest hotel: Hotel Tamasite
# kahului - nearest hotel: Maui Seaside Hotel
# gat - nearest hotel: מלון גולדן טאוור
# laguna - nearest hotel: Holiday Inn Express & Suites
# tikaitnagar - nearest hotel: Maa patesawri sweet hous
# comodoro rivadavia - nearest hotel: No hotel found
# san quintin - nearest hotel: Jardines Hotel
# santa rosalia - nearest hotel: Sol y Mar
# pemba - nearest hotel: Hotel Rafael
# narwar - nearest hotel: Shivpuri Hotel
# port hedland - nearest hotel: The Esplanade Hotel
# roebourne - nearest hotel: Ibis Styles Karratha
# ...

# %%
#import json
#name_address = requests.get(base_url, params=params)
#name_address =  name_address.json()
#print(json.dumps(name_address, indent=2))
# Out:
# {
#   "statusCode": 400,
#   "error": "Bad Request",
#   "message": "\"filter[0]\" does not match any of the allowed types"
# }

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot = hotel_df.hvplot.points(
    x='Lng',  # Replace 'longitude' with the actual column name containing longitude values
    y='Lat',  # Replace 'latitude' with the actual column name containing latitude values
    c='Humidity',  # Replace 'humidity' with the actual column name containing humidity values
    geo=True,  # Enable geographic projection
    size='Humidity',  # Set the size of the points to represent humidity
    color='blue',  # Set the color of the points
    alpha=0.7,  # Set the transparency of the points
    tiles = "EsriNatGeo",
    hover_cols=['City', 'Humidity','Hotel Name','Country'],  # Show city and humidity in the hover tooltip
    width=800,  # Set the width of the plot
    height=500  # Set the height of the plot
)

# Display the map
# YOUR CODE HERE
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Hotel Name,Country)
