# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from time import sleep
# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "history.openweathermap.org/data/2.5/aggregated/year?lat={lat_range}&lon={lng_range}&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = [cities]

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | farsund
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lanzhou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | colorado
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# ...

# %%
cities
# Out:
# ['iqaluit',
#  'adamstown',
#  'albany',
#  'hawaiian paradise park',
#  'invercargill',
#  'puerto deseado',
#  'new norfolk',
#  'codrington',
#  'balangiga',
#  'puerto natales',
#  'punta arenas',
#  'petropavlovsk-kamchatsky',
#  'olot',
#  'yellowknife',
#  'devinuwara',
#  'pisco',
#  'boguchany',
#  'magadan',
#  'porbandar',
#  'port mathurin',
#  'ribeira grande',
#  'bredasdorp',
#  'orumiyeh',
#  'olonkinbyen',
#  'grytviken',
#  'badger',
#  'sisimiut',
#  'port-aux-francais',
#  'baymak',
#  'kani keli',
#  'sitka',
#  'katsuura',
#  'as sulayyil',
#  'ponta delgada',
#  'port lincoln',
#  'soligalich',
#  'nukunonu',
#  'rongelap',
#  'santa lucia',
#  'lihue',
#  'chamical',
#  'udachny',
#  'talara',
#  'saint-pierre',
#  'blackmans bay',
#  'hasaki',
#  'keflavik',
#  'soma',
#  'bethel',
#  'kavaratti',
#  'longyearbyen',
#  'mutoko',
#  'atafu village',
#  "st. john's",
#  'tagta',
#  'ballina',
#  'colonia',
#  'chonchi',
#  'nuuk',
#  'gargalianoi',
# ...

# %%
url = f"https://api.openweathermap.org/data/2.5/weather?"
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
record_count = 1
set_count = 1


for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    city_url = url + f"q={city}&appid={weather_api_key}"
    #print(city_url)
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1

    try:
        response= requests.get(city_url)
        city_weather = response.json()
        #print(city_weather)
     
        city_lat = city_weather['coord']["lat"] # YOUR CODE HERE
        city_lng = city_weather['coord']["lon"]# YOUR CODE HERE
        city_max_temp = city_weather['main']["temp_max"]# YOUR CODE HERE
        city_humidity = city_weather['main']['humidity']# YOUR CODE HERE
        city_clouds = city_weather['weather'][0]['main']# YOUR CODE HERE
        city_wind = city_weather['wind']['speed']# YOUR CODE HERE
        city_country = city_weather['sys']['country']# YOUR CODE HERE
        city_date =city_weather['dt']
        
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    except:
        print("City not found. Skipping...")
        pass
                
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nova vicosa
# Processing Record 2 of Set 1 | menaka
# Processing Record 3 of Set 1 | tazovsky
# Processing Record 4 of Set 1 | kiruna
# Processing Record 5 of Set 1 | esquel
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | island harbour
# Processing Record 8 of Set 1 | sao joao do piaui
# Processing Record 9 of Set 1 | bac lieu
# Processing Record 10 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 1 | volodarskiy
# Processing Record 12 of Set 1 | port lincoln
# Processing Record 13 of Set 1 | kristiansund
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | badagry
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | edinburgh of the seven seas
# Processing Record 18 of Set 1 | zheleznodorozhnyy
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | isafjordur
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat      Lng  Max Temp  Humidity Cloudiness  Wind Speed  \
# 0  nova vicosa -17.8919 -39.3719    298.93        70     Clouds        3.46
# 1       menaka  15.9182   2.4022    314.32        19     Clouds        5.80
# 2     tazovsky  67.4667  78.7000    276.15        95     Clouds        4.63
# 3       kiruna  67.8557  20.2251    286.66        51      Clear        6.17
# 4       esquel -42.9000 -71.3167    276.81        94     Clouds        0.58
#
#   Country        Date
# 0      BR  1686847070
# 1      ML  1686847071
# 2      RU  1686847071
# 3      SE  1686847072
# 4      AR  1686846953

# %%
city_data_df.head()
# Out:
#           City      Lat      Lng  Max Temp  Humidity Cloudiness  Wind Speed  \
# 0  nova vicosa -17.8919 -39.3719    298.93        70     Clouds        3.46
# 1       menaka  15.9182   2.4022    314.32        19     Clouds        5.80
# 2     tazovsky  67.4667  78.7000    276.15        95     Clouds        4.63
# 3       kiruna  67.8557  20.2251    286.66        51      Clear        6.17
# 4       esquel -42.9000 -71.3167    276.81        94     Clouds        0.58
#
#   Country        Date
# 0      BR  1686847070
# 1      ML  1686847071
# 2      RU  1686847071
# 3      SE  1686847072
# 4      AR  1686846953

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 0        nova vicosa -17.8919 -39.3719    298.93        70     Clouds
# 1             menaka  15.9182   2.4022    314.32        19     Clouds
# 2           tazovsky  67.4667  78.7000    276.15        95     Clouds
# 3             kiruna  67.8557  20.2251    286.66        51      Clear
# 4             esquel -42.9000 -71.3167    276.81        94     Clouds
#
#          Wind Speed Country        Date
# City_ID
# 0              3.46      BR  1686847070
# 1              5.80      ML  1686847071
# 2              4.63      RU  1686847071
# 3              6.17      SE  1686847072
# 4              0.58      AR  1686846953

# %%
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 0        nova vicosa -17.8919 -39.3719    298.93        70     Clouds
# 1             menaka  15.9182   2.4022    314.32        19     Clouds
# 2           tazovsky  67.4667  78.7000    276.15        95     Clouds
# 3             kiruna  67.8557  20.2251    286.66        51      Clear
# 4             esquel -42.9000 -71.3167    276.81        94     Clouds
#
#          Wind Speed Country        Date
# City_ID
# 0              3.46      BR  1686847070
# 1              5.80      ML  1686847071
# 2              4.63      RU  1686847071
# 3              6.17      SE  1686847072
# 4              0.58      AR  1686846953

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %%
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8),
              title="City Latitude vs Max Temperature (2022-10-18)")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
city_data_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8),
              title="City Latitude vs Humidity (2022-10-18)")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8),
              title="City Latitude vs Cloudiness (2022-10-18)")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8),
              title="City Latitude vs Wind Speed  (2022-10-18)")
plt.savefig("../output_data/Fig1.png")
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 1                menaka  15.9182    2.4022    314.32        19     Clouds
# 2              tazovsky  67.4667   78.7000    276.15        95     Clouds
# 3                kiruna  67.8557   20.2251    286.66        51      Clear
# 6        island harbour  50.7240   -1.2758    299.28        61     Clouds
# 8              bac lieu   9.2850  105.7244    301.06        80     Clouds
#
#          Wind Speed Country        Date
# City_ID
# 1              5.80      ML  1686847071
# 2              4.63      RU  1686847071
# 3              6.17      SE  1686847072
# 6              4.66      GB  1686847075
# 8              4.61      VN  1686847078

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %%
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity Cloudiness  \
# City_ID
# 0              nova vicosa -17.8919  -39.3719    298.93        70     Clouds
# 4                   esquel -42.9000  -71.3167    276.81        94     Clouds
# 5                adamstown -25.0660 -130.1015    294.46        68     Clouds
# 7        sao joao do piaui  -8.3581  -42.2467    309.09        26      Clear
# 10            port lincoln -34.7333  135.8667    286.54        64      Clear
#
#          Wind Speed Country        Date
# City_ID
# 0              3.46      BR  1686847070
# 4              0.58      AR  1686846953
# 5              4.82      PN  1686847074
# 7              3.91      BR  1686847077
# 10             7.83      AU  1686847081

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
northern_hemi_df.plot(kind="scatter", x="Lat", y="Max Temp")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (northern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(10,280),fontsize=15,color="red")
plt.plot(northern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is -0.7174145199710491

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %%
southern_hemi_df.plot(kind="scatter", x="Lat", y="Max Temp")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (southern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(-50,305),fontsize=15,color="red")
plt.plot(southern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is 0.8345775121724032

# %%
# both of these graphs have a inverse relationship as you get close to the equator or a lat of 0 the higher the temp you will see.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
northern_hemi_df.plot(kind="scatter", x="Lat", y="Humidity")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (northern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.plot(northern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is -0.006989900408981047

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %%
southern_hemi_df.plot(kind="scatter", x="Lat", y="Humidity")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (southern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.plot(southern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is -0.08599462846682153

# %%
# For these two graphs is looks like in northern hemisphere humidity is not to defined by Lat and in the southern hemisphere there is a slight decrease in humidity as lat goes towards 0

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
northern_hemi_df.plot(kind="scatter", x="Lat", y="Cloudiness")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (northern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.plot(northern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 northern_hemi_df.plot(kind="scatter", x="Lat", y="Cloudiness")
# ----> 2 (pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
#       3 #pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
#       4 regress_values = (northern_hemi_df['Lat']) * pe_slope + pe_int
#
# File ~\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:162, in linregress(x, y, alternative)
#     160 n = len(x)
#     161 xmean = np.mean(x, None)
# --> 162 ymean = np.mean(y, None)
#     164 # Average sums of square differences from the mean
#     165 #   ssxm = mean( (x-mean(x))^2 )
#     166 #   ssxym = mean( (x-mean(x)) * (y-mean(y)) )
#     167 ssxm, ssxym, _, ssym = np.cov(x, y, bias=1).flat
#
# ...

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %%
southern_hemi_df.plot(kind="scatter", x="Lat", y="Humidity")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (southern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.plot(southern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
northern_hemi_df.plot(kind="scatter", x="Lat", y="Wind Speed")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (northern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.plot(northern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is -0.0042443136250398346

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %%
southern_hemi_df.plot(kind="scatter", x="Lat", y="Wind Speed")
(pe_slope, pe_int, pe_r, pe_p, pe_std_err) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
#pe_fit = pe_slope * (pnc_adi["ADI_STATERANK"]) + pe_int
regress_values = (southern_hemi_df['Lat']) * pe_slope + pe_int
line_eq = "y = " + str(round(pe_slope,2)) + "x + " + str(round(pe_int,2))
plt.annotate(line_eq,(-50,15),fontsize=15,color="red")
plt.plot(southern_hemi_df["Lat"],regress_values,"r--")
plt.show()
print(f"R-Value is {pe_r}")
# Out:
# R-Value is -0.22925852507614583

# %%
# for Wind speed in the northern hemisphere it seams to not be related to lat but for the southern hemisphere winds spead decreases as lat decrease towards 0.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
